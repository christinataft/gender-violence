# %%
import json
import pandas as pd
import re
import string
import numpy as np
import pickle

# %% [markdown]
# ## Load data

# %%
with open("../data/raw/text.json") as json_file:
    data = json.load(json_file)

df_text = pd.DataFrame(data)
# make sure there are no missing values
df_text.dropna(axis=0, how='any', inplace=True)
df_text.shape
# Out:
# (2685, 2)

# %%
df_text
# Out:
#                                            file_id  \
# 0                1ZEZSJXkKDSIyDULhRKfHXCLXpm-eYY0Z
# 1                1srRixiO6V3FMxoumtAxMfEPblqoD8-gn
# 2     1kpIno_4VKnxAcfmpXihrqTkpPbr15EvG4nqwfD6-xqc
# 3                1LHE9syGgdHcRRA7Ns9X31UPdYVy-GVJf
# 4                1N_D97m1WHrO9PqVpULeT1t_E0pI7XwO4
# ...                                            ...
# 2729  1KlV9Qcsff6ouhoSa-obG_Ci-FGgcPyp-zpYMsPYDjcQ
# 2730  1tgQM3WYrdelhcozMMDB_6-hP_3CuvOlNWkcCfSxUgaw
# 2731             1DrlPAykTylCmuLOnHnCeuuJXl70gq_Q-
# 2732                  0B9wNhp3GjjazWHRubGpjY0VXMEU
# 2733                  0B9wNhp3GjjazTTV2Y3JwazRXQWc
#
#                                                    text
# 0      Buenos Aires,     de junio de 2019. AUTOS Y V...
# 1      Buenos Aires,       de diciembre de 2019. En ...
# 2     Resumen: resolución interlocutoria por la que ...
# 3                                                   ...
# 4      Buenos Aires,   11    de enero de 2019. La in...
# ...                                                 ...
# 2729  Resumen: resolución interlocutoria que rechaza...
# 2730  AUDIENCIA DE PRUEBA (Art. 210 CPP) VIDEOCONFER...
# 2731  ACTA DE AUDIENCIA “ XX s/ Art. 67 CC 2do párr-...
# 2732  Buenos Aires, 27 de junio de 2017 Hora de inic...
# 2733  Buenos Aires, 27 de junio de 2017 Hora de inic...
#
# [2685 rows x 2 columns]

# %%
df_meta = pd.read_csv("../data/processed/metadata_test.csv", index_col=0)
# We will focus exclusively on cases of gender violence
df_meta = df_meta[df_meta['VIOLENCIA_DE_GENERO'] == 1]
df_meta
# Out:
#            N NRO_REGISTRO FECHA_RESOLUCION                       FIRMA  \
# 1871  1655.0         1810       15_02_2019                 Pablo_Casas
# 598    577.0          829       13_09_2017                 Pablo_Casas
# 3362  2753.0         2862         15_07_20                 Pablo_Casas
# 179    185.0          672        2_12_2016                 Pablo_Casas
# 3144     NaN         2695         26_02_20                 Pablo_Casas
# ...      ...          ...              ...                         ...
# 2682     NaN         2368       23_09_2019                 Pablo_Casas
# 2676  2237.0         2364       19_09_2019  juez_interinamente_a_cargo
# 1189  1106.0         1302        15_6_2018                 Pablo_Casas
# 96      99.0          NaN        28_9_2016                 Pablo_Casas
# 2795  2320.0         2445       23_10_2019                 Pablo_Casas
#
#               MATERIA ART_INFRINGIDO               CODIGO_O_LEY  \
# 1871  contravencional             52     codigo_contravencional
# 598             penal         149bis  codigo_penal_de_la_nacion
# 3362            penal             92  codigo_penal_de_la_nacion
# 179   contravencional             52     codigo_contravencional
# 3144            penal         149bis  codigo_penal_de_la_nacion
# ...               ...            ...                        ...
# 2682            penal         189bis  codigo_penal_de_la_nacion
# 2676            penal             92  codigo_penal_de_la_nacion
# 1189            penal         149bis  codigo_penal_de_la_nacion
# 96    contravencional             52     codigo_contravencional
# 2795            penal         149bis  codigo_penal_de_la_nacion
#
#               CONDUCTA CONDUCTA_DESCRIPCION  VIOLENCIA_DE_GENERO  ...  \
# 1871     hostigamiento                  NaN                    1  ...
# 598           amenazas              simples                    1  ...
# 3362          lesiones             agravado                    1  ...
# 179      hostigamiento                  NaN                    1  ...
# 3144          amenazas              simples                    1  ...
# ...                ...                  ...                  ...  ...
# 2682  tenencia_de_arma   de_fuego_uso_civil                    1  ...
# 2676          lesiones      leves_agravadas                    1  ...
# 1189          amenazas              simples                    1  ...
# 96       hostigamiento                  NaN                    1  ...
# 2795          amenazas              simples                    1  ...
#
#      N_REGISTRO_Y_TOMO_CAMARA_2 LINK_CAMARA_2 DECISION_DE_FONDO_TSJ  \
# 1871                        NaN           NaN                   NaN
# 598                         NaN           NaN                   NaN
# 3362                        NaN           NaN                   NaN
# 179                         NaN           NaN                   NaN
# 3144                        NaN           NaN                   NaN
# ...                         ...           ...                   ...
# 2682                        NaN           NaN                   NaN
# 2676                        NaN           NaN                   NaN
# 1189                         No            No                    No
# 96                          NaN           NaN                   NaN
# 2795                        NaN           NaN                   NaN
#
#      N_REGISTRO_Y_TOMO_TSJ LINK_TSJ RECURSO_EXTRAORDINARIO_Y_RECURRENTE  \
# 1871                   NaN      NaN                                 NaN
# 598                    NaN      NaN                                 NaN
# 3362                   NaN      NaN                                 NaN
# 179                    NaN      NaN                                 NaN
# 3144                   NaN      NaN                                 NaN
# ...                    ...      ...                                 ...
# 2682                   NaN      NaN                                 NaN
# 2676                   NaN      NaN                                 NaN
# 1189                   NaN      NaN                                 NaN
# 96                     NaN      NaN                                 NaN
# 2795                   NaN      NaN                                 NaN
#
#      DECISION_CSJN N_REGISTRO_Y_TOMO_CSJN LINK_CSJN  \
# 1871           NaN                    NaN       NaN
# 598            NaN                    NaN       NaN
# 3362           NaN                    NaN       NaN
# 179            NaN                    NaN       NaN
# 3144           NaN                    NaN       NaN
# ...            ...                    ...       ...
# 2682           NaN                    NaN       NaN
# 2676           NaN                    NaN       NaN
# 1189           NaN                    NaN       NaN
# 96             NaN                    NaN       NaN
# 2795           NaN                    NaN       NaN
#
#                                            file_id
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0
# 3362             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu
# 179                   0B9wNhp3GjjazUlJ2aGNfV3NWWDA
# 3144             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY
# ...                                            ...
# 2682             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii
# 2676             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE
#
# [80 rows x 62 columns]

# %%
df = pd.merge(df_meta, df_text, 
              on='file_id', how='inner', 
              right_index=True)
df.shape
# Out:
# (78, 63)

# %%
df
# Out:
#            N NRO_REGISTRO FECHA_RESOLUCION                       FIRMA  \
# 1871  1655.0         1810       15_02_2019                 Pablo_Casas
# 598    577.0          829       13_09_2017                 Pablo_Casas
# 3362  2753.0         2862         15_07_20                 Pablo_Casas
# 179    185.0          672        2_12_2016                 Pablo_Casas
# 3144     NaN         2695         26_02_20                 Pablo_Casas
# ...      ...          ...              ...                         ...
# 2682     NaN         2368       23_09_2019                 Pablo_Casas
# 2676  2237.0         2364       19_09_2019  juez_interinamente_a_cargo
# 1189  1106.0         1302        15_6_2018                 Pablo_Casas
# 96      99.0          NaN        28_9_2016                 Pablo_Casas
# 2795  2320.0         2445       23_10_2019                 Pablo_Casas
#
#               MATERIA ART_INFRINGIDO               CODIGO_O_LEY  \
# 1871  contravencional             52     codigo_contravencional
# 598             penal         149bis  codigo_penal_de_la_nacion
# 3362            penal             92  codigo_penal_de_la_nacion
# 179   contravencional             52     codigo_contravencional
# 3144            penal         149bis  codigo_penal_de_la_nacion
# ...               ...            ...                        ...
# 2682            penal         189bis  codigo_penal_de_la_nacion
# 2676            penal             92  codigo_penal_de_la_nacion
# 1189            penal         149bis  codigo_penal_de_la_nacion
# 96    contravencional             52     codigo_contravencional
# 2795            penal         149bis  codigo_penal_de_la_nacion
#
#               CONDUCTA CONDUCTA_DESCRIPCION  VIOLENCIA_DE_GENERO  ...  \
# 1871     hostigamiento                  NaN                    1  ...
# 598           amenazas              simples                    1  ...
# 3362          lesiones             agravado                    1  ...
# 179      hostigamiento                  NaN                    1  ...
# 3144          amenazas              simples                    1  ...
# ...                ...                  ...                  ...  ...
# 2682  tenencia_de_arma   de_fuego_uso_civil                    1  ...
# 2676          lesiones      leves_agravadas                    1  ...
# 1189          amenazas              simples                    1  ...
# 96       hostigamiento                  NaN                    1  ...
# 2795          amenazas              simples                    1  ...
#
#      LINK_CAMARA_2 DECISION_DE_FONDO_TSJ N_REGISTRO_Y_TOMO_TSJ LINK_TSJ  \
# 1871           NaN                   NaN                   NaN      NaN
# 598            NaN                   NaN                   NaN      NaN
# 3362           NaN                   NaN                   NaN      NaN
# 179            NaN                   NaN                   NaN      NaN
# 3144           NaN                   NaN                   NaN      NaN
# ...            ...                   ...                   ...      ...
# 2682           NaN                   NaN                   NaN      NaN
# 2676           NaN                   NaN                   NaN      NaN
# 1189            No                    No                   NaN      NaN
# 96             NaN                   NaN                   NaN      NaN
# 2795           NaN                   NaN                   NaN      NaN
#
#      RECURSO_EXTRAORDINARIO_Y_RECURRENTE DECISION_CSJN N_REGISTRO_Y_TOMO_CSJN  \
# 1871                                 NaN           NaN                    NaN
# 598                                  NaN           NaN                    NaN
# 3362                                 NaN           NaN                    NaN
# 179                                  NaN           NaN                    NaN
# 3144                                 NaN           NaN                    NaN
# ...                                  ...           ...                    ...
# 2682                                 NaN           NaN                    NaN
# 2676                                 NaN           NaN                    NaN
# 1189                                 NaN           NaN                    NaN
# 96                                   NaN           NaN                    NaN
# 2795                                 NaN           NaN                    NaN
#
#      LINK_CSJN                                       file_id  \
# 1871       NaN             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg
# 598        NaN                  0B9wNhp3GjjazbTkyblEyWDVCcU0
# 3362       NaN             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu
# 179        NaN                  0B9wNhp3GjjazUlJ2aGNfV3NWWDA
# 3144       NaN             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY
# ...        ...                                           ...
# 2682       NaN             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii
# 2676       NaN             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja
# 1189       NaN  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8
# 96         NaN                  0B9wNhp3GjjazejRSMURGNU5BcUU
# 2795       NaN             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE
#
#                                                    text
# 1871   ACTA DE AUDIENCIA “XX s/ ART. 52 HOSTIGAR, MA...
# 598   Buenos Aires, 13 de septiembre de 2017 Causa N...
# 3362    AUDIENCIA DE PRUEBA (Art. 210 CPP) VIDEOCONF...
# 179   <1> \n\n=� \n,---�?. \n§8\n\n¡·\ \n\nV \n\n�--...
# 3144  RESOLUCION INTERLOCUTORIA Rechaza la excepción...
# ...                                                 ...
# 2682  ACTA DE AUDIENCIA “XX y otros s. 149BIS – AMEN...
# 2676   ACTA DE AUDIENCIA “XX SOBRE 89  - LESIONES LE...
# 1189  Buenos Aires, 15 de junio de 2018. Solicitud d...
# 96    llJ  � \n·- :, \n=  (IS \no> \n...J .¡; \nCl1 ...
# 2795   ACTA DE AUDIENCIA “ XX SOBRE 149 BIS - AMENAZ...
#
# [78 rows x 63 columns]

# %% [markdown]
# ## Predict probabilities

# %%
vect_path = str("../models/gender_violence_vectorizer.sav")
with open(vect_path, 'rb') as f:
    vectorizer_gender_violence = pickle.load(f)
    print(vectorizer_gender_violence)
# Out:
# Pipeline(steps=[('preprocessor',
#                  <text_preprocessing.TextPreprocessor object at 0x7f8fb28eb250>),
#                 ('vectorizer',
#                  TfidfVectorizer(max_df=0.85, min_df=0.1,
#                                  tokenizer=<text_preprocessing.SpacyTokenizer object at 0x7f8fb295a760>))])

# %%
# vectorize text
text_features = vectorizer_gender_violence.transform(df.text)

# %%
# load best model
model_path = str("../models/gender_violence_model.sav")
with open(model_path, 'rb') as f:
    gender_violence_model = pickle.load(f)

# get predictions
gender_violence_proba = gender_violence_model.predict_proba(text_features)
gender_violence_proba = gender_violence_proba[:,1]
len(gender_violence_proba)
# Out:
# 78

# %%
# load vectorizer
vect_path = str("../models/violence_type_vectorizer.sav")
with open(vect_path, 'rb') as f:
    vectorizer_violence_type = pickle.load(f)
    print(vectorizer_violence_type)

# vectorize text
text_features = vectorizer_violence_type.transform(df.text)
# Out:
# Pipeline(steps=[('preprocessor',
#                  <text_preprocessing.TextPreprocessor object at 0x7f8f8e6de9d0>),
#                 ('vectorizer',
#                  TfidfVectorizer(max_df=0.85, min_df=0.1,
#                                  tokenizer=<text_preprocessing.SpacyTokenizer object at 0x7f8f8e6de190>))])

# %%
# load best model
model_path = str("../models/violence_type_model.sav")
with open(model_path, 'rb') as f:
    violence_type_model = pickle.load(f)

target_vars = ["V_FISICA", "V_PSIC", "V_ECON", "V_SEX",
               "V_SOC", "V_AMB", "V_SIMB"]

# get predictions for each type of violence
predicted_probas = {}
for var in target_vars:
    model = violence_type_model[var]['fitted_model']
    col_name = str(var + "_proba")
    predicted_probas[col_name] = model.predict_proba(text_features)[:,1]

# %%
# consolidate results
df_probas = pd.DataFrame({'file_id': df.file_id, 'gender_violence_proba': gender_violence_proba})
df_probas.reset_index(drop=True, inplace=True)

# %%
df_probas = pd.concat([df_probas, pd.DataFrame(predicted_probas)], axis=1)
len(df_probas)
# Out:
# 78

# %%
df_probas.set_index(df.index, inplace=True)
df_probas
# Out:
#                                            file_id  gender_violence_proba  \
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg               0.714492
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0               0.526438
# 3362             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu               0.802236
# 179                   0B9wNhp3GjjazUlJ2aGNfV3NWWDA               0.920000
# 3144             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY               0.969636
# ...                                            ...                    ...
# 2682             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii               0.989868
# 2676             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja               0.570576
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8               0.880000
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU               0.697669
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE               0.840743
#
#       V_FISICA_proba  V_PSIC_proba  V_ECON_proba  V_SEX_proba  V_SOC_proba  \
# 1871        0.150000      0.988806      0.075000         0.01     0.069999
# 598         0.280000      0.896549      0.455000         0.19     0.160987
# 3362        0.950000      0.890221      0.071224         0.05     0.037253
# 179         0.840000      0.694358      0.110000         0.02     0.095422
# 3144        0.850000      0.988178      0.640000         0.73     0.055347
# ...              ...           ...           ...          ...          ...
# 2682        0.980000      0.995620      0.035000         0.02     0.006320
# 2676        0.563889      0.790525      0.270000         0.06     0.190171
# 1189        0.850000      0.988145      0.758067         0.08     0.711254
# 96          0.580000      0.981541      0.147199         0.04     0.251227
# 2795        0.810000      0.790444      0.070000         0.02     0.087617
#
#       V_AMB_proba  V_SIMB_proba
# 1871     0.040000      0.939651
# 598      0.040000      0.649925
# 3362     0.060000      0.893951
# 179      0.030000      0.959612
# 3144     0.060000      0.999758
# ...           ...           ...
# 2682     0.990000      0.994612
# 2676     0.080000      0.854273
# 1189     0.050000      0.988560
# 96       0.189192      0.932527
# 2795     0.020000      0.863644
#
# [78 rows x 9 columns]

# %% [markdown]
# ## Generate features

# %%
# get the names of features use for training
file = open("../models/column_names.txt","r+") 
col_names = file.read().split(",")
col_names.remove("")
col_names
# Out:
# ['file_id',
#  'MATERIA',
#  'GENERO_ACUSADO/A',
#  'NACIONALIDAD_ACUSADO/A',
#  'NIVEL_INSTRUCCION_ACUSADO/A',
#  'GENERO_DENUNCIANTE',
#  'NACIONALIDAD_DENUNCIANTE',
#  'FRECUENCIA_EPISODIOS',
#  'RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE',
#  'HIJOS/AS_EN_COMUN',
#  'TIPO_DE_RESOLUCION']

# %%
df = df[col_names]
original_index = df.index
df
# Out:
#                                            file_id          MATERIA  \
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg  contravencional
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0            penal
# 3362             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu            penal
# 179                   0B9wNhp3GjjazUlJ2aGNfV3NWWDA  contravencional
# 3144             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY            penal
# ...                                            ...              ...
# 2682             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii            penal
# 2676             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja            penal
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8            penal
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU  contravencional
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE            penal
#
#      GENERO_ACUSADO/A NACIONALIDAD_ACUSADO/A NIVEL_INSTRUCCION_ACUSADO/A  \
# 1871        masculino              argentino       secundario_incompleto
# 598         masculino              argentino           primario_completo
# 3362        masculino              argentino      universitario_completo
# 179         masculino              argentino         secundario_completo
# 3144        masculino              paraguayo           primario_completo
# ...               ...                    ...                         ...
# 2682        masculino              argentino       secundario_incompleto
# 2676        masculino              argentino        terciario_incompleto
# 1189        masculino              argentino                         NaN
# 96          masculino                    NaN                         NaN
# 2795        masculino              boliviano         secundario_completo
#
#      GENERO_DENUNCIANTE NACIONALIDAD_DENUNCIANTE FRECUENCIA_EPISODIOS  \
# 1871           femenino                argentina          primera_vez
# 598            femenino                argentina             eventual
# 3362           femenino                      NaN                  NaN
# 179            femenino                  peruana          primera_vez
# 3144           femenino                paraguaya             habitual
# ...                 ...                      ...                  ...
# 2682           femenino                argentina             eventual
# 2676           femenino                argentina             habitual
# 1189           femenino               venezolana             habitual
# 96             femenino                  Peruana             habitual
# 2795           femenino                boliviana           esporadico
#
#      RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE HIJOS/AS_EN_COMUN  \
# 1871                                     ex_pareja                 1
# 598                                      ex_pareja                 0
# 3362                                           NaN               NaN
# 179                                      ex_pareja                 1
# 3144                                     ex_pareja                 1
# ...                                            ...               ...
# 2682                                     ex_pareja                 1
# 2676                                     ex_pareja                 1
# 1189                                        pareja                 0
# 96                                       ex_pareja                 0
# 2795                                     ex_pareja                 1
#
#      TIPO_DE_RESOLUCION
# 1871     interlocutoria
# 598      interlocutoria
# 3362     interlocutoria
# 179          definitiva
# 3144     interlocutoria
# ...                 ...
# 2682     interlocutoria
# 2676     interlocutoria
# 1189     interlocutoria
# 96       interlocutoria
# 2795     interlocutoria
#
# [78 rows x 11 columns]

# %%
# make all responses lowercase
for var in list(col_names):
    if var == "file_id":
        continue
    else:
        df[var] = df[var].str.lower()
# Out:
# <ipython-input-17-fcf0667ded4b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[var] = df[var].str.lower()

# %%
# load imputer previosly used
with open("../models/metadata_imp.sav", 'rb') as f:
    meta_imputer = pickle.load(f)

# %%
df_imp = meta_imputer.transform(df)
# reconvert the imputed data into a pandas DataFrame
df_imp = pd.DataFrame(df_imp, index=original_index, columns=df.columns)
df_imp
# Out:
#                                            file_id          MATERIA  \
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg  contravencional
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0            penal
# 3362             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu            penal
# 179                   0B9wNhp3GjjazUlJ2aGNfV3NWWDA  contravencional
# 3144             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY            penal
# ...                                            ...              ...
# 2682             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii            penal
# 2676             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja            penal
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8            penal
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU  contravencional
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE            penal
#
#      GENERO_ACUSADO/A NACIONALIDAD_ACUSADO/A NIVEL_INSTRUCCION_ACUSADO/A  \
# 1871        masculino              argentino       secundario_incompleto
# 598         masculino              argentino           primario_completo
# 3362        masculino              argentino      universitario_completo
# 179         masculino              argentino         secundario_completo
# 3144        masculino              paraguayo           primario_completo
# ...               ...                    ...                         ...
# 2682        masculino              argentino       secundario_incompleto
# 2676        masculino              argentino        terciario_incompleto
# 1189        masculino              argentino       secundario_incompleto
# 96          masculino              argentino       secundario_incompleto
# 2795        masculino              boliviano         secundario_completo
#
#      GENERO_DENUNCIANTE NACIONALIDAD_DENUNCIANTE FRECUENCIA_EPISODIOS  \
# 1871           femenino                argentina          primera_vez
# 598            femenino                argentina             eventual
# 3362           femenino                argentina             habitual
# 179            femenino                  peruana          primera_vez
# 3144           femenino                paraguaya             habitual
# ...                 ...                      ...                  ...
# 2682           femenino                argentina             eventual
# 2676           femenino                argentina             habitual
# 1189           femenino               venezolana             habitual
# 96             femenino                  peruana             habitual
# 2795           femenino                boliviana           esporadico
#
#      RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE HIJOS/AS_EN_COMUN  \
# 1871                                     ex_pareja                 1
# 598                                      ex_pareja                 0
# 3362                                     ex_pareja                 1
# 179                                      ex_pareja                 1
# 3144                                     ex_pareja                 1
# ...                                            ...               ...
# 2682                                     ex_pareja                 1
# 2676                                     ex_pareja                 1
# 1189                                        pareja                 0
# 96                                       ex_pareja                 0
# 2795                                     ex_pareja                 1
#
#      TIPO_DE_RESOLUCION
# 1871     interlocutoria
# 598      interlocutoria
# 3362     interlocutoria
# 179          definitiva
# 3144     interlocutoria
# ...                 ...
# 2682     interlocutoria
# 2676     interlocutoria
# 1189     interlocutoria
# 96       interlocutoria
# 2795     interlocutoria
#
# [78 rows x 11 columns]

# %%
cols = list(df_imp.columns)
cols.remove('file_id')
# generate dummies from categorical columns
df_features = pd.get_dummies(df_imp, columns=cols)
df_features
# Out:
#                                            file_id  MATERIA_contravencional  \
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg                        1
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0                        0
# 3362             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu                        0
# 179                   0B9wNhp3GjjazUlJ2aGNfV3NWWDA                        1
# 3144             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY                        0
# ...                                            ...                      ...
# 2682             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii                        0
# 2676             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja                        0
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8                        0
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU                        1
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE                        0
#
#       MATERIA_penal  GENERO_ACUSADO/A_masculino  \
# 1871              0                           1
# 598               1                           1
# 3362              1                           1
# 179               0                           1
# 3144              1                           1
# ...             ...                         ...
# 2682              1                           1
# 2676              1                           1
# 1189              1                           1
# 96                0                           1
# 2795              1                           1
#
#       NACIONALIDAD_ACUSADO/A_argentino  NACIONALIDAD_ACUSADO/A_boliviano  \
# 1871                                 1                                 0
# 598                                  1                                 0
# 3362                                 1                                 0
# 179                                  1                                 0
# 3144                                 0                                 0
# ...                                ...                               ...
# 2682                                 1                                 0
# 2676                                 1                                 0
# 1189                                 1                                 0
# 96                                   1                                 0
# 2795                                 0                                 1
#
#       NACIONALIDAD_ACUSADO/A_español  NACIONALIDAD_ACUSADO/A_paraguayo  \
# 1871                               0                                 0
# 598                                0                                 0
# 3362                               0                                 0
# 179                                0                                 0
# 3144                               0                                 1
# ...                              ...                               ...
# 2682                               0                                 0
# 2676                               0                                 0
# 1189                               0                                 0
# 96                                 0                                 0
# 2795                               0                                 0
#
#       NACIONALIDAD_ACUSADO/A_peruano  \
# 1871                               0
# 598                                0
# 3362                               0
# 179                                0
# 3144                               0
# ...                              ...
# 2682                               0
# 2676                               0
# 1189                               0
# 96                                 0
# 2795                               0
#
#       NIVEL_INSTRUCCION_ACUSADO/A_primario_completo  ...  \
# 1871                                              0  ...
# 598                                               1  ...
# 3362                                              0  ...
# 179                                               0  ...
# 3144                                              1  ...
# ...                                             ...  ...
# 2682                                              0  ...
# 2676                                              0  ...
# 1189                                              0  ...
# 96                                                0  ...
# 2795                                              0  ...
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_ex_pareja  \
# 1871                                                  1
# 598                                                   1
# 3362                                                  1
# 179                                                   1
# 3144                                                  1
# ...                                                 ...
# 2682                                                  1
# 2676                                                  1
# 1189                                                  0
# 96                                                    1
# 2795                                                  1
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_familiar  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_ninguna  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_pareja  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  1
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_profesor  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_vecino/a  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       HIJOS/AS_EN_COMUN_0  HIJOS/AS_EN_COMUN_1  TIPO_DE_RESOLUCION_definitiva  \
# 1871                    0                    1                              0
# 598                     1                    0                              0
# 3362                    0                    1                              0
# 179                     0                    1                              1
# 3144                    0                    1                              0
# ...                   ...                  ...                            ...
# 2682                    0                    1                              0
# 2676                    0                    1                              0
# 1189                    1                    0                              0
# 96                      1                    0                              0
# 2795                    0                    1                              0
#
#       TIPO_DE_RESOLUCION_interlocutoria
# 1871                                  1
# 598                                   1
# 3362                                  1
# 179                                   0
# 3144                                  1
# ...                                 ...
# 2682                                  1
# 2676                                  1
# 1189                                  1
# 96                                    1
# 2795                                  1
#
# [78 rows x 39 columns]

# %%
file = open("../models/features_names.txt","r+") 
features_names = file.read().split(",")
features_names.remove("")

# %%
features_filter = [feature for feature in features_names if feature in list(df_features.columns)]
df_features = df_features[features_filter]
df_features
# Out:
#                                            file_id  MATERIA_contravencional  \
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg                        1
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0                        0
# 3362             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu                        0
# 179                   0B9wNhp3GjjazUlJ2aGNfV3NWWDA                        1
# 3144             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY                        0
# ...                                            ...                      ...
# 2682             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii                        0
# 2676             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja                        0
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8                        0
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU                        1
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE                        0
#
#       MATERIA_penal  GENERO_ACUSADO/A_masculino  \
# 1871              0                           1
# 598               1                           1
# 3362              1                           1
# 179               0                           1
# 3144              1                           1
# ...             ...                         ...
# 2682              1                           1
# 2676              1                           1
# 1189              1                           1
# 96                0                           1
# 2795              1                           1
#
#       NACIONALIDAD_ACUSADO/A_argentino  NACIONALIDAD_ACUSADO/A_boliviano  \
# 1871                                 1                                 0
# 598                                  1                                 0
# 3362                                 1                                 0
# 179                                  1                                 0
# 3144                                 0                                 0
# ...                                ...                               ...
# 2682                                 1                                 0
# 2676                                 1                                 0
# 1189                                 1                                 0
# 96                                   1                                 0
# 2795                                 0                                 1
#
#       NACIONALIDAD_ACUSADO/A_español  NACIONALIDAD_ACUSADO/A_paraguayo  \
# 1871                               0                                 0
# 598                                0                                 0
# 3362                               0                                 0
# 179                                0                                 0
# 3144                               0                                 1
# ...                              ...                               ...
# 2682                               0                                 0
# 2676                               0                                 0
# 1189                               0                                 0
# 96                                 0                                 0
# 2795                               0                                 0
#
#       NACIONALIDAD_ACUSADO/A_peruano  \
# 1871                               0
# 598                                0
# 3362                               0
# 179                                0
# 3144                               0
# ...                              ...
# 2682                               0
# 2676                               0
# 1189                               0
# 96                                 0
# 2795                               0
#
#       NIVEL_INSTRUCCION_ACUSADO/A_primario_completo  ...  \
# 1871                                              0  ...
# 598                                               1  ...
# 3362                                              0  ...
# 179                                               0  ...
# 3144                                              1  ...
# ...                                             ...  ...
# 2682                                              0  ...
# 2676                                              0  ...
# 1189                                              0  ...
# 96                                                0  ...
# 2795                                              0  ...
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_ex_pareja  \
# 1871                                                  1
# 598                                                   1
# 3362                                                  1
# 179                                                   1
# 3144                                                  1
# ...                                                 ...
# 2682                                                  1
# 2676                                                  1
# 1189                                                  0
# 96                                                    1
# 2795                                                  1
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_familiar  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_ninguna  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_pareja  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  1
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_profesor  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_vecino/a  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       HIJOS/AS_EN_COMUN_0  HIJOS/AS_EN_COMUN_1  TIPO_DE_RESOLUCION_definitiva  \
# 1871                    0                    1                              0
# 598                     1                    0                              0
# 3362                    0                    1                              0
# 179                     0                    1                              1
# 3144                    0                    1                              0
# ...                   ...                  ...                            ...
# 2682                    0                    1                              0
# 2676                    0                    1                              0
# 1189                    1                    0                              0
# 96                      1                    0                              0
# 2795                    0                    1                              0
#
#       TIPO_DE_RESOLUCION_interlocutoria
# 1871                                  1
# 598                                   1
# 3362                                  1
# 179                                   0
# 3144                                  1
# ...                                 ...
# 2682                                  1
# 2676                                  1
# 1189                                  1
# 96                                    1
# 2795                                  1
#
# [78 rows x 39 columns]

# %%
# However, now there might be columns that were in the 
# training dataset but not in the test new
# We are going to add them with zero values for all rows

not_in_test = [f for f in features_names if f not in list(df_features.columns)]

for f in not_in_test:
    df_features = df_features.join(pd.DataFrame({f: [0]*df_features.shape[0]}))
    
#lastly, we need to give the columns the same order as they had in the training data
df_features = df_features[features_names]
df_features.drop(columns=['file_id'], inplace=True)
df_features.replace(np.nan, 0, inplace=True)
df_features
# Out:
#       MATERIA_contravencional  MATERIA_penal  GENERO_ACUSADO/A_masculino  \
# 1871                        1              0                           1
# 598                         0              1                           1
# 3362                        0              1                           1
# 179                         1              0                           1
# 3144                        0              1                           1
# ...                       ...            ...                         ...
# 2682                        0              1                           1
# 2676                        0              1                           1
# 1189                        0              1                           1
# 96                          1              0                           1
# 2795                        0              1                           1
#
#       NACIONALIDAD_ACUSADO/A_argentino  NACIONALIDAD_ACUSADO/A_armenio  \
# 1871                                 1                             0.0
# 598                                  1                             0.0
# 3362                                 1                             0.0
# 179                                  1                             0.0
# 3144                                 0                             0.0
# ...                                ...                             ...
# 2682                                 1                             0.0
# 2676                                 1                             0.0
# 1189                                 1                             0.0
# 96                                   1                             0.0
# 2795                                 0                             0.0
#
#       NACIONALIDAD_ACUSADO/A_boliviano  NACIONALIDAD_ACUSADO/A_brasilero  \
# 1871                                 0                               0.0
# 598                                  0                               0.0
# 3362                                 0                               0.0
# 179                                  0                               0.0
# 3144                                 0                               0.0
# ...                                ...                               ...
# 2682                                 0                               0.0
# 2676                                 0                               0.0
# 1189                                 0                               0.0
# 96                                   0                               0.0
# 2795                                 1                               0.0
#
#       NACIONALIDAD_ACUSADO/A_dominicano  NACIONALIDAD_ACUSADO/A_español  \
# 1871                                0.0                               0
# 598                                 0.0                               0
# 3362                                0.0                               0
# 179                                 0.0                               0
# 3144                                0.0                               0
# ...                                 ...                             ...
# 2682                                0.0                               0
# 2676                                0.0                               0
# 1189                                0.0                               0
# 96                                  0.0                               0
# 2795                                0.0                               0
#
#       NACIONALIDAD_ACUSADO/A_italiano  ...  \
# 1871                              0.0  ...
# 598                               0.0  ...
# 3362                              0.0  ...
# 179                               0.0  ...
# 3144                              0.0  ...
# ...                               ...  ...
# 2682                              0.0  ...
# 2676                              0.0  ...
# 1189                              0.0  ...
# 96                                0.0  ...
# 2795                              0.0  ...
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_pareja  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  1
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_profesor  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_propietario_del_inmueble_de_residencia  \
# 1871                                                0.0
# 598                                                 0.0
# 3362                                                0.0
# 179                                                 0.0
# 3144                                                0.0
# ...                                                 ...
# 2682                                                0.0
# 2676                                                0.0
# 1189                                                0.0
# 96                                                  0.0
# 2795                                                0.0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_vecino/a  \
# 1871                                                  0
# 598                                                   0
# 3362                                                  0
# 179                                                   0
# 3144                                                  0
# ...                                                 ...
# 2682                                                  0
# 2676                                                  0
# 1189                                                  0
# 96                                                    0
# 2795                                                  0
#
#       RELACION_Y_TIPO_ENTRE_ACUSADO/A_Y_DENUNCIANTE_zona_sur  \
# 1871                                                0.0
# 598                                                 0.0
# 3362                                                0.0
# 179                                                 0.0
# 3144                                                0.0
# ...                                                 ...
# 2682                                                0.0
# 2676                                                0.0
# 1189                                                0.0
# 96                                                  0.0
# 2795                                                0.0
#
#       HIJOS/AS_EN_COMUN_0  HIJOS/AS_EN_COMUN_1  \
# 1871                    0                    1
# 598                     1                    0
# 3362                    0                    1
# 179                     0                    1
# 3144                    0                    1
# ...                   ...                  ...
# 2682                    0                    1
# 2676                    0                    1
# 1189                    1                    0
# 96                      1                    0
# 2795                    0                    1
#
#       HIJOS/AS_EN_COMUN_en_domicilio_particular  \
# 1871                                        0.0
# 598                                         0.0
# 3362                                        0.0
# 179                                         0.0
# 3144                                        0.0
# ...                                         ...
# 2682                                        0.0
# 2676                                        0.0
# 1189                                        0.0
# 96                                          0.0
# 2795                                        0.0
#
#       TIPO_DE_RESOLUCION_definitiva  TIPO_DE_RESOLUCION_interlocutoria
# 1871                              0                                  1
# 598                               0                                  1
# 3362                              0                                  1
# 179                               1                                  0
# 3144                              0                                  1
# ...                             ...                                ...
# 2682                              0                                  1
# 2676                              0                                  1
# 1189                              0                                  1
# 96                                0                                  1
# 2795                              0                                  1
#
# [78 rows x 58 columns]

# %%
df_final = df_features.join(df_probas)
df_final
# Out:
#       MATERIA_contravencional  MATERIA_penal  GENERO_ACUSADO/A_masculino  \
# 1871                        1              0                           1
# 598                         0              1                           1
# 3362                        0              1                           1
# 179                         1              0                           1
# 3144                        0              1                           1
# ...                       ...            ...                         ...
# 2682                        0              1                           1
# 2676                        0              1                           1
# 1189                        0              1                           1
# 96                          1              0                           1
# 2795                        0              1                           1
#
#       NACIONALIDAD_ACUSADO/A_argentino  NACIONALIDAD_ACUSADO/A_armenio  \
# 1871                                 1                             0.0
# 598                                  1                             0.0
# 3362                                 1                             0.0
# 179                                  1                             0.0
# 3144                                 0                             0.0
# ...                                ...                             ...
# 2682                                 1                             0.0
# 2676                                 1                             0.0
# 1189                                 1                             0.0
# 96                                   1                             0.0
# 2795                                 0                             0.0
#
#       NACIONALIDAD_ACUSADO/A_boliviano  NACIONALIDAD_ACUSADO/A_brasilero  \
# 1871                                 0                               0.0
# 598                                  0                               0.0
# 3362                                 0                               0.0
# 179                                  0                               0.0
# 3144                                 0                               0.0
# ...                                ...                               ...
# 2682                                 0                               0.0
# 2676                                 0                               0.0
# 1189                                 0                               0.0
# 96                                   0                               0.0
# 2795                                 1                               0.0
#
#       NACIONALIDAD_ACUSADO/A_dominicano  NACIONALIDAD_ACUSADO/A_español  \
# 1871                                0.0                               0
# 598                                 0.0                               0
# 3362                                0.0                               0
# 179                                 0.0                               0
# 3144                                0.0                               0
# ...                                 ...                             ...
# 2682                                0.0                               0
# 2676                                0.0                               0
# 1189                                0.0                               0
# 96                                  0.0                               0
# 2795                                0.0                               0
#
#       NACIONALIDAD_ACUSADO/A_italiano  ...  TIPO_DE_RESOLUCION_interlocutoria  \
# 1871                              0.0  ...                                  1
# 598                               0.0  ...                                  1
# 3362                              0.0  ...                                  1
# 179                               0.0  ...                                  0
# 3144                              0.0  ...                                  1
# ...                               ...  ...                                ...
# 2682                              0.0  ...                                  1
# 2676                              0.0  ...                                  1
# 1189                              0.0  ...                                  1
# 96                                0.0  ...                                  1
# 2795                              0.0  ...                                  1
#
#                                            file_id  gender_violence_proba  \
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg               0.714492
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0               0.526438
# 3362             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu               0.802236
# 179                   0B9wNhp3GjjazUlJ2aGNfV3NWWDA               0.920000
# 3144             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY               0.969636
# ...                                            ...                    ...
# 2682             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii               0.989868
# 2676             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja               0.570576
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8               0.880000
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU               0.697669
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE               0.840743
#
#       V_FISICA_proba  V_PSIC_proba  V_ECON_proba  V_SEX_proba  V_SOC_proba  \
# 1871        0.150000      0.988806      0.075000         0.01     0.069999
# 598         0.280000      0.896549      0.455000         0.19     0.160987
# 3362        0.950000      0.890221      0.071224         0.05     0.037253
# 179         0.840000      0.694358      0.110000         0.02     0.095422
# 3144        0.850000      0.988178      0.640000         0.73     0.055347
# ...              ...           ...           ...          ...          ...
# 2682        0.980000      0.995620      0.035000         0.02     0.006320
# 2676        0.563889      0.790525      0.270000         0.06     0.190171
# 1189        0.850000      0.988145      0.758067         0.08     0.711254
# 96          0.580000      0.981541      0.147199         0.04     0.251227
# 2795        0.810000      0.790444      0.070000         0.02     0.087617
#
#       V_AMB_proba  V_SIMB_proba
# 1871     0.040000      0.939651
# 598      0.040000      0.649925
# 3362     0.060000      0.893951
# 179      0.030000      0.959612
# 3144     0.060000      0.999758
# ...           ...           ...
# 2682     0.990000      0.994612
# 2676     0.080000      0.854273
# 1189     0.050000      0.988560
# 96       0.189192      0.932527
# 2795     0.020000      0.863644
#
# [78 rows x 67 columns]

# %% [markdown]
# ## Generate predictions

# %%
X = df_final.drop(columns=["file_id"])
X
# Out:
#       MATERIA_contravencional  MATERIA_penal  GENERO_ACUSADO/A_masculino  \
# 1871                        1              0                           1
# 598                         0              1                           1
# 3362                        0              1                           1
# 179                         1              0                           1
# 3144                        0              1                           1
# ...                       ...            ...                         ...
# 2682                        0              1                           1
# 2676                        0              1                           1
# 1189                        0              1                           1
# 96                          1              0                           1
# 2795                        0              1                           1
#
#       NACIONALIDAD_ACUSADO/A_argentino  NACIONALIDAD_ACUSADO/A_armenio  \
# 1871                                 1                             0.0
# 598                                  1                             0.0
# 3362                                 1                             0.0
# 179                                  1                             0.0
# 3144                                 0                             0.0
# ...                                ...                             ...
# 2682                                 1                             0.0
# 2676                                 1                             0.0
# 1189                                 1                             0.0
# 96                                   1                             0.0
# 2795                                 0                             0.0
#
#       NACIONALIDAD_ACUSADO/A_boliviano  NACIONALIDAD_ACUSADO/A_brasilero  \
# 1871                                 0                               0.0
# 598                                  0                               0.0
# 3362                                 0                               0.0
# 179                                  0                               0.0
# 3144                                 0                               0.0
# ...                                ...                               ...
# 2682                                 0                               0.0
# 2676                                 0                               0.0
# 1189                                 0                               0.0
# 96                                   0                               0.0
# 2795                                 1                               0.0
#
#       NACIONALIDAD_ACUSADO/A_dominicano  NACIONALIDAD_ACUSADO/A_español  \
# 1871                                0.0                               0
# 598                                 0.0                               0
# 3362                                0.0                               0
# 179                                 0.0                               0
# 3144                                0.0                               0
# ...                                 ...                             ...
# 2682                                0.0                               0
# 2676                                0.0                               0
# 1189                                0.0                               0
# 96                                  0.0                               0
# 2795                                0.0                               0
#
#       NACIONALIDAD_ACUSADO/A_italiano  ...  TIPO_DE_RESOLUCION_definitiva  \
# 1871                              0.0  ...                              0
# 598                               0.0  ...                              0
# 3362                              0.0  ...                              0
# 179                               0.0  ...                              1
# 3144                              0.0  ...                              0
# ...                               ...  ...                            ...
# 2682                              0.0  ...                              0
# 2676                              0.0  ...                              0
# 1189                              0.0  ...                              0
# 96                                0.0  ...                              0
# 2795                              0.0  ...                              0
#
#       TIPO_DE_RESOLUCION_interlocutoria  gender_violence_proba  \
# 1871                                  1               0.714492
# 598                                   1               0.526438
# 3362                                  1               0.802236
# 179                                   0               0.920000
# 3144                                  1               0.969636
# ...                                 ...                    ...
# 2682                                  1               0.989868
# 2676                                  1               0.570576
# 1189                                  1               0.880000
# 96                                    1               0.697669
# 2795                                  1               0.840743
#
#       V_FISICA_proba  V_PSIC_proba  V_ECON_proba  V_SEX_proba  V_SOC_proba  \
# 1871        0.150000      0.988806      0.075000         0.01     0.069999
# 598         0.280000      0.896549      0.455000         0.19     0.160987
# 3362        0.950000      0.890221      0.071224         0.05     0.037253
# 179         0.840000      0.694358      0.110000         0.02     0.095422
# 3144        0.850000      0.988178      0.640000         0.73     0.055347
# ...              ...           ...           ...          ...          ...
# 2682        0.980000      0.995620      0.035000         0.02     0.006320
# 2676        0.563889      0.790525      0.270000         0.06     0.190171
# 1189        0.850000      0.988145      0.758067         0.08     0.711254
# 96          0.580000      0.981541      0.147199         0.04     0.251227
# 2795        0.810000      0.790444      0.070000         0.02     0.087617
#
#       V_AMB_proba  V_SIMB_proba
# 1871     0.040000      0.939651
# 598      0.040000      0.649925
# 3362     0.060000      0.893951
# 179      0.030000      0.959612
# 3144     0.060000      0.999758
# ...           ...           ...
# 2682     0.990000      0.994612
# 2676     0.080000      0.854273
# 1189     0.050000      0.988560
# 96       0.189192      0.932527
# 2795     0.020000      0.863644
#
# [78 rows x 66 columns]

# %%
# load best model
model_path = str("../models/complete_model.sav")
with open(model_path, 'rb') as f:
    complete_model = pickle.load(f)

# %%
complete_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4c545856aa4d> in <module>
# ----> 1 complete_model
#
# NameError: name 'complete_model' is not defined

# %%
target_vars = ["V_FISICA", "V_PSIC", "V_ECON", "V_SEX",
               "V_SOC", "V_AMB", "V_SIMB"]

# get predictions for each type of violence
predictions = {}
for var in target_vars:
    model = complete_model['gridcv'][var]['fitted_model']
    col_name = str(var + "_pred")
    predictions[col_name] = model.predict(X)

# %%
predictions = pd.DataFrame(predictions, index=X.index)
predictions
# Out:
#       V_FISICA_pred  V_PSIC_pred  V_ECON_pred  V_SEX_pred  V_SOC_pred  \
# 1871              0            1            0           0           0
# 598               0            0            0           0           0
# 3362              1            1            0           0           0
# 179               1            1            0           0           0
# 3144              1            1            1           1           0
# ...             ...          ...          ...         ...         ...
# 2682              1            1            0           0           0
# 2676              1            1            0           0           0
# 1189              1            1            1           0           1
# 96                1            1            0           0           0
# 2795              1            1            0           0           0
#
#       V_AMB_pred  V_SIMB_pred
# 1871           0            1
# 598            0            1
# 3362           0            1
# 179            0            1
# 3144           0            1
# ...          ...          ...
# 2682           1            1
# 2676           0            1
# 1189           0            1
# 96             0            1
# 2795           0            1
#
# [78 rows x 7 columns]

# %% [markdown]
# ## Evaluate model

# %%
y = pd.read_csv("../data/processed/target_vars_test.csv", index_col=0)
y
# Out:
#                                            file_id  VIOLENCIA_DE_GENERO  \
# 1718             1iW7U2yEvu-LS6TLo1nxP5bceWCV5ng8A                    0
# 1871             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg                    1
# 598                   0B9wNhp3GjjazbTkyblEyWDVCcU0                    1
# 3233             1AFvaihoOqtF1aNf9GNkxe1gTeRDXSp5s                    0
# 690              1fHzd-xwdemgFpHiq0glrLcwgs0jYvyOM                    0
# ...                                            ...                  ...
# 2435             180ZWXDC5z5-AYEZYz0rCgmh1waJVJ-n6                    0
# 1189  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8                    1
# 96                    0B9wNhp3GjjazejRSMURGNU5BcUU                    1
# 2795             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE                    1
# 2074             1PeBSCVvZpOcGNUzQFJh2e1rgOkQCoubE                    0
#
#             V_FISICA          V_PSIC          V_ECON           V_SEX  \
# 1718  no_corresponde  no_corresponde  no_corresponde  no_corresponde
# 1871               0               1               0               0
# 598                1               1               0               0
# 3233  no_corresponde  no_corresponde  no_corresponde  no_corresponde
# 690   no_corresponde  no_corresponde  no_corresponde  no_corresponde
# ...              ...             ...             ...             ...
# 2435  no_corresponde  no_corresponde  no_corresponde  no_corresponde
# 1189               1               1               1               0
# 96                 0               1               0               0
# 2795               1               1               0               0
# 2074  no_corresponde  no_corresponde  no_corresponde  no_corresponde
#
#                V_SOC           V_AMB          V_SIMB
# 1718  no_corresponde  no_corresponde  no_corresponde
# 1871               0               0               1
# 598                0               0               1
# 3233  no_corresponde  no_corresponde  no_corresponde
# 690   no_corresponde  no_corresponde  no_corresponde
# ...              ...             ...             ...
# 2435  no_corresponde  no_corresponde  no_corresponde
# 1189               1               0               1
# 96                 0               0               1
# 2795               0               0               1
# 2074  no_corresponde  no_corresponde  no_corresponde
#
# [343 rows x 9 columns]

# %%
results = predictions.join(y)
results
# Out:
#       V_FISICA_pred  V_PSIC_pred  V_ECON_pred  V_SEX_pred  V_SOC_pred  \
# 1871              0            1            0           0           0
# 598               0            0            0           0           0
# 3362              1            1            0           0           0
# 179               1            1            0           0           0
# 3144              1            1            1           1           0
# ...             ...          ...          ...         ...         ...
# 2682              1            1            0           0           0
# 2676              1            1            0           0           0
# 1189              1            1            1           0           1
# 96                1            1            0           0           0
# 2795              1            1            0           0           0
#
#       V_AMB_pred  V_SIMB_pred                                       file_id  \
# 1871           0            1             1ui2-sTtmwtq5CTIcwGYs6__ffMEHqFyg
# 598            0            1                  0B9wNhp3GjjazbTkyblEyWDVCcU0
# 3362           0            1             1Ix43U_-cc6EyYFNtekOQqVsaYV3dnRhu
# 179            0            1                  0B9wNhp3GjjazUlJ2aGNfV3NWWDA
# 3144           0            1             1AygkwBWx3kTfgpqKUNS5Hz0xmipUy8vY
# ...          ...          ...                                           ...
# 2682           1            1             1Jm7ioiBCmgJDWx7O_5meoAatVhY_J4Ii
# 2676           0            1             1g3zKkiQ1n8KcXzOF8b7rOixFCkD4dlja
# 1189           0            1  1VBwFMBy4cuPCnO2FoIh3wY55JfjJJLfLS2am1vMW9d8
# 96             0            1                  0B9wNhp3GjjazejRSMURGNU5BcUU
# 2795           0            1             1GICSuiv-b8_0eTaWNGOJX1EIhNIK2mIE
#
#       VIOLENCIA_DE_GENERO V_FISICA V_PSIC V_ECON V_SEX V_SOC V_AMB V_SIMB
# 1871                    1        0      1      0     0     0     0      1
# 598                     1        1      1      0     0     0     0      1
# 3362                    1        1      1      0     0     0     0      1
# 179                     1        1      1      0     0     0     0      1
# 3144                    1        1      1      1     1     0     0      1
# ...                   ...      ...    ...    ...   ...   ...   ...    ...
# 2682                    1        1      1      0     0     0     1      1
# 2676                    1        1      1      0     1     1     0      1
# 1189                    1        1      1      1     0     1     0      1
# 96                      1        0      1      0     0     0     0      1
# 2795                    1        1      1      0     0     0     0      1
#
# [78 rows x 16 columns]

# %%
results[str(target_vars[0])].unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

for var in target_vars:
    y_test = results[var].astype(int)
    y_hat = results[str(var + "_pred")]
    
    print("\n**** Results for %s variable ****\n" % var)
    
    print(" Accuracy: %s" % accuracy_score(y_test, y_hat))
    
    print(" F1: %s" % f1_score(y_test, y_hat))
    
    print(" Precision: %s" % precision_score(y_test, y_hat))
    
    print(" Recall: %s" % recall_score(y_test, y_hat))
# Out:
# **** Results for V_FISICA variable ****
#
#  Accuracy: 0.9102564102564102
#  F1: 0.9292929292929293
#  Precision: 0.9387755102040817
#  Recall: 0.92
#
# **** Results for V_PSIC variable ****
#
#  Accuracy: 0.9743589743589743
#  F1: 0.9861111111111112
#  Precision: 0.9861111111111112
#  Recall: 0.9861111111111112
#
# **** Results for V_ECON variable ****
#
#  Accuracy: 0.9743589743589743
#  F1: 0.9411764705882353
#  Precision: 1.0
#  Recall: 0.8888888888888888
#
# **** Results for V_SEX variable ****
#
#  Accuracy: 0.9743589743589743
#  F1: 0.8
#  Precision: 1.0
#  Recall: 0.6666666666666666
#
# **** Results for V_SOC variable ****
#
#  Accuracy: 0.9615384615384616
#  F1: 0.9090909090909091
#  Precision: 1.0
#  Recall: 0.8333333333333334
#
# **** Results for V_AMB variable ****
#
#  Accuracy: 0.9871794871794872
#  F1: 0.923076923076923
#  Precision: 1.0
#  Recall: 0.8571428571428571
#
# **** Results for V_SIMB variable ****
#
#  Accuracy: 0.9871794871794872
#  F1: 0.993103448275862
#  Precision: 0.9863013698630136
#  Recall: 1.0
